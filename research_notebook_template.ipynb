# %% [markdown]
# # Research Notebook Template\n\nUse this notebook to document experiments, hypotheses, parameter changes, and results.\n

# %%
import pandas as pd\nfrom pathlib import Path\n\nresults = Path('../results')\nbacktest = pd.read_csv(results / 'backtest.csv', parse_dates=['date'])\nbacktest.head()\n
